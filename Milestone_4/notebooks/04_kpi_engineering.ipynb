# %% [markdown]
# # EduVision_DV — KPI Engineering
# Loads and inspects the six required KPIs.

# %%
import pandas as pd
kpi=pd.read_csv("../data_final/kpi_dataset.csv")
print(kpi.columns.tolist())
print(kpi.head())
