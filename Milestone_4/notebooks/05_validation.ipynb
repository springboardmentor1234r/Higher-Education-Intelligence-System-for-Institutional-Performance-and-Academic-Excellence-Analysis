# %% [markdown]
# # EduVision_DV — Validation
# Checks duplicate rows, key completeness and final table sizes.

# %%
import pandas as pd
from pathlib import Path
for path in Path("../data_final").glob("*.csv"):
    df=pd.read_csv(path)
    print(f"{path.name}: {len(df):,} rows x {df.shape[1]} columns | duplicate rows={df.duplicated().sum():,}")
