# %% [markdown]
# # EduVision_DV — Data Loading
# Loads the four supplied datasets and records their dimensions.

# %%
import pandas as pd
from pathlib import Path
ROOT=Path("..")
files={
"QS 2025":ROOT/"data_final/qs_2025_raw.csv",
"THE 2024":ROOT/"data_final/the_2024_raw.csv",
"WUR 2023":ROOT/"data_final/wur_2023_raw.csv",
"Country education":ROOT/"data_final/world_education_raw.csv",
}
for name,path in files.items():
    df=pd.read_csv(path)
    print(name, df.shape)
