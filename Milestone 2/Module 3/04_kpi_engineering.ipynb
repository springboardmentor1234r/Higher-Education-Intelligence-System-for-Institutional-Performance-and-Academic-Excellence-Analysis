# %% [markdown]
# # EduVision_DV - Step 4: Education KPI Engineering
# **Milestone 2: Module 3: Education KPI Engineering**
#
# This notebook calculates and documents the six core Higher Education Key Performance Indicators (KPIs) strictly adhering to Section 20-24 of the Project Guide:
# 1. **Global Ranking Score**: Institutional performance score (0-100)
# 2. **Research Impact Score**: Normalized citation impact per academic unit (0-100)
# 3. **Faculty-to-Student Ratio**: Actual staff-student ratio (students per staff)
# 4. **International Student Percentage**: Proportion of international degree-seeking students (%)
# 5. **Academic Reputation Score**: Global academic peer survey score (0-100)
# 6. **Research Productivity Index**: Defensible composite index ($0.50 \times \text{Research} + 0.30 \times \text{Citation} + 0.20 \times \text{Collaboration}$)

# %%
import os
import pandas as pd
import numpy as np

# Execute KPI generation
from scripts.generate_education_kpis import main as run_kpis
run_kpis()

# Load generated KPI master dataset
kpi_df = pd.read_csv('04_kpi_dataset/kpi_master.csv')
print('KPI Dataset Shape:', kpi_df.shape)
kpi_df.head()

# %% [markdown]
# ## Summary Statistics of the 6 KPIs
# Evaluation criteria: All KPIs correctly calculated, with no arbitrary substitutions.

# %%
kpi_cols = [
    'kpi_global_ranking_score',
    'kpi_research_impact_score',
    'kpi_faculty_student_ratio',
    'kpi_international_student_pct',
    'kpi_academic_reputation_score',
    'kpi_research_productivity_index'
]
kpi_df[kpi_cols].describe()
