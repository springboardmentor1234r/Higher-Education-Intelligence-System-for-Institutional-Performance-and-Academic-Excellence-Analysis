# %%
import pandas as pd


df = pd.read_csv("../data/university_raw_data.csv")

# Display basic information
print("Dataset shape:", df.shape)
print("\nColumn names:")
print(df.columns.tolist())

print("\nFirst 5 rows:")
display(df.head())
# Out:
# Dataset shape: (850, 26)
#
# Column names:
# ['University_Key', 'University_Name_QS', 'Country_QS', 'Country_Code', 'QS_Rank', 'QS_Overall_Score', 'QS_Academic_Reputation', 'QS_Employer_Reputation', 'QS_Faculty_Student_Score', 'QS_Citations_Per_Faculty', 'QS_International_Faculty', 'QS_International_Students', 'University_Name_THE', 'Country_THE', 'THE_Rank', 'THE_Overall_Score', 'THE_Teaching_Score', 'THE_Research_Score', 'THE_Citations_Score', 'THE_Industry_Income_Score', 'THE_International_Outlook', 'Total_Students', 'Student_Staff_Ratio', 'International_Students', 'Female_Male_Ratio', 'Year']
#
# First 5 rows:
#                           University_Key  \
# 0  massachusetts institute of technology
# 1                university of cambridge
# 2                   university of oxford
# 3                     harvard university
# 4                    stanford university
#
#                              University_Name_QS      Country_QS Country_Code  \
# 0  Massachusetts Institute of Technology (MIT)    United States           US
# 1                       University of Cambridge  United Kingdom           UK
# 2                          University of Oxford  United Kingdom           UK
# 3                            Harvard University   United States           US
# 4                           Stanford University   United States           US
#
#   QS_Rank QS_Overall_Score  QS_Academic_Reputation  QS_Employer_Reputation  \
# 0       1            100.0                   100.0                   100.0
# 1       2             99.2                   100.0                   100.0
# 2       3             98.9                   100.0                   100.0
# 3       4             98.3                   100.0                   100.0
# 4       5             98.1                   100.0                   100.0
#
#    QS_Faculty_Student_Score  QS_Citations_Per_Faculty  ...  \
# 0                     100.0                     100.0  ...
# 1                     100.0                      92.3  ...
# 2                     100.0                      90.6  ...
# 3                      98.3                     100.0  ...
# 4                     100.0                      99.9  ...
#
#    THE_Teaching_Score  THE_Research_Score THE_Citations_Score  \
# 0                98.6                96.2                99.7
# 1                95.8               100.0                98.0
# 2                96.6               100.0                99.0
# 3                97.7                99.9                99.4
# 4                99.0                97.8                99.6
#
#   THE_Industry_Income_Score  THE_International_Outlook Total_Students  \
# 0                     100.0                       93.8         11,085
# 1                      87.9                       97.4         20,565
# 2                      98.7                       97.5         21,750
# 3                      84.2                       90.8         20,050
# 4                     100.0                       87.0         14,517
#
#    Student_Staff_Ratio  International_Students  Female_Male_Ratio  Year
# 0                  8.0                     33%           41:59:00  2024
# 1                 11.5                     38%           48:52:00  2024
# 2                 10.9                     42%           49:51:00  2024
# 3                  9.0                     25%           51:49:00  2024
# 4                  6.4                     23%           47:53:00  2024
#
# [5 rows x 26 columns]

# %%
# Check duplicate rows
print("Duplicate rows:", df.duplicated().sum())

# Check missing values
missing = df.isnull().sum()

print("\nMissing values:")
print(missing[missing > 0])

# Missing percentage
print("\nMissing percentage:")
print((missing[missing > 0] / len(df) * 100).round(2))
# Out:
# Duplicate rows: 0
#
# Missing values:
# QS_Faculty_Student_Score     11
# QS_Citations_Per_Faculty     11
# QS_International_Faculty     38
# QS_International_Students    20
# Female_Male_Ratio            52
# dtype: int64
#
# Missing percentage:
# QS_Faculty_Student_Score     1.29
# QS_Citations_Per_Faculty     1.29
# QS_International_Faculty     4.47
# QS_International_Students    2.35
# Female_Male_Ratio            6.12
# dtype: float64

# %%
# Fill missing numerical values with the median

missing_columns = [
    "QS_Faculty_Student_Score",
    "QS_Citations_Per_Faculty",
    "QS_International_Faculty",
    "QS_International_Students",
    "Female_Male_Ratio"
]

for col in missing_columns:
    df[col] = pd.to_numeric(df[col], errors="coerce")
    df[col] = df[col].fillna(df[col].median())

print("Missing values after cleaning:")
print(df.isnull().sum()[df.isnull().sum() > 0])

print("\nTotal missing values:", df.isnull().sum().sum())
# Out:
# Missing values after cleaning:
# Series([], dtype: int64)
#
# Total missing values: 0

# %%
# Check data types

print("Data types:")
print(df.dtypes)

print("\nDataset shape:", df.shape)
# Out:
# Data types:
# University_Key                   str
# University_Name_QS               str
# Country_QS                       str
# Country_Code                     str
# QS_Rank                          str
# QS_Overall_Score                 str
# QS_Academic_Reputation       float64
# QS_Employer_Reputation       float64
# QS_Faculty_Student_Score     float64
# QS_Citations_Per_Faculty     float64
# QS_International_Faculty     float64
# QS_International_Students    float64
# University_Name_THE              str
# Country_THE                      str
# THE_Rank                     float64
# THE_Overall_Score                str
# THE_Teaching_Score           float64
# THE_Research_Score           float64
# THE_Citations_Score          float64
# THE_Industry_Income_Score    float64
# THE_International_Outlook    float64
# Total_Students                   str
# Student_Staff_Ratio          float64
# International_Students           str
# Female_Male_Ratio            float64
# Year                           int64
# dtype: object
#
# Dataset shape: (850, 26)

# %%
# Convert important columns to numeric

numeric_columns = [
    "QS_Rank",
    "QS_Overall_Score",
    "THE_Overall_Score",
    "Total_Students",
    "International_Students"
]

for col in numeric_columns:
    df[col] = pd.to_numeric(df[col], errors="coerce")

print("Numeric columns converted successfully.")

print("\nUpdated data types:")
print(df[numeric_columns].dtypes)
# Out:
# Numeric columns converted successfully.
#
# Updated data types:
# QS_Rank                   float64
# QS_Overall_Score          float64
# THE_Overall_Score         float64
# Total_Students            float64
# International_Students    float64
# dtype: object

# %%
# Check missing values after type conversion

missing = df.isnull().sum()

print("Missing values:")
print(missing[missing > 0])

print("\nTotal missing values:", df.isnull().sum().sum())
# Out:
# Missing values:
# QS_Rank                   699
# QS_Overall_Score          435
# THE_Overall_Score         702
# Total_Students            849
# International_Students    850
# dtype: int64
#
# Total missing values: 3535

# %%
# Fill missing numeric values with median

for col in numeric_columns:
    df[col] = df[col].fillna(df[col].median())

print("Missing values after cleaning:")
missing = df.isnull().sum()
print(missing[missing > 0])

print("\nTotal missing values:", df.isnull().sum().sum())
# Out:
# Missing values after cleaning:
# International_Students    850
# dtype: int64
#
# Total missing values: 850

# %%
# Remove the completely empty column

df = df.drop(columns=["International_Students"])

print("Column removed successfully.")
print("Dataset shape:", df.shape)

print("\nTotal missing values:", df.isnull().sum().sum())
# Out:
# Column removed successfully.
# Dataset shape: (850, 25)
#
# Total missing values: 0

# %%
# Check duplicate universities

print("Duplicate University Names:")
print(df["University_Name_QS"].duplicated().sum())

print("\nDuplicate rows:")
print(df.duplicated().sum())
# Out:
# Duplicate University Names:
# 0
#
# Duplicate rows:
# 0

# %%
# Save cleaned dataset

output_path = "../data/university_cleaned_data.csv"

df.to_csv(output_path, index=False)

print("Cleaned dataset saved successfully!")
print("Saved to:", output_path)
print("Final shape:", df.shape)
# Out:
# Cleaned dataset saved successfully!
# Saved to: ../data/university_cleaned_data.csv
# Final shape: (850, 25)

# %%
# Save the cleaned dataset

output_path = "../data/university_cleaned.csv"

df.to_csv(output_path, index=False)

print("Cleaned dataset saved successfully.")
print("Saved to:", output_path)
print("Final dataset shape:", df.shape)
# Out:
# Cleaned dataset saved successfully.
# Saved to: ../data/university_cleaned.csv
# Final dataset shape: (850, 25)
